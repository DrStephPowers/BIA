# %% [markdown]
# <a href="https://colab.research.google.com/github/DrStephPowers/BIA/blob/main/App_DataPrep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import Data from Excel

# %%
df = pd.read_excel('/content/drive/MyDrive/BI BA Handbook/Chapter 4/bargainclean.xlsx')
df.head(4)
# Out:
#    Respondent                Q1         Q2   Q3  \
# 0           1    Increasing pay  Full Time  3.0
# 1           2  Improve benefits  Full Time  1.0
# 2           3      Job security  Part Time  NaN
# 3           4      Job security  Part Time  NaN
#
#                                    Q4            Q5  Q6   Q7  Q8a  Q8b  ...  \
# 0  Additional funding for Counselling            No   1   No    1    3  ...
# 1                       Drug coverage           Yes   3  Yes    3    4  ...
# 2                                 NaN            No   1   No    3    1  ...
# 3                                 NaN  I don't know   4   No    3    2  ...
#
#    Q15                                               Q16  Q17  Q18  \
# 0    4                                               NaN  0.0    4
# 1    2             Be able to work from home once a week  0.0    3
# 2    3                                Give me more hours  0.0    3
# 3    2  more flexibility on work from home for part time  0.0    4
#
# ...

# %% [markdown]
# Import Data from CSV

# %%
df = 'pd.read_csv(path\filename.csv')

# %% [markdown]
# ## Separate Open Option from List

# %%
df["Q4a"] = df['Q4']
df.head(4)
# Out:
#    Respondent                Q1         Q2   Q3  \
# 0           1    Increasing pay  Full Time  3.0
# 1           2  Improve benefits  Full Time  1.0
# 2           3      Job security  Part Time  NaN
# 3           4      Job security  Part Time  NaN
#
#                                    Q4            Q5  Q6   Q7  Q8a  Q8b  ...  \
# 0  Additional funding for Counselling            No   1   No    1    3  ...
# 1                       Drug coverage           Yes   3  Yes    3    4  ...
# 2                                 NaN            No   1   No    3    1  ...
# 3                                 NaN  I don't know   4   No    3    2  ...
#
#                                                 Q16  Q17  Q18  \
# 0                                               NaN  0.0    4
# 1             Be able to work from home once a week  0.0    3
# 2                                Give me more hours  0.0    3
# 3  more flexibility on work from home for part time  0.0    4
#
# ...

# %%
df["Q4a"].replace({"Wellness account": 1, "Health spending account": 2,
"Massage" : 3, "Chiropractic care" : 4, "Dental" :  5, "Drug coverage" : 6}, inplace=True)
df.head(4)
# Out:
#    Respondent                Q1         Q2   Q3  \
# 0           1    Increasing pay  Full Time  3.0
# 1           2  Improve benefits  Full Time  1.0
# 2           3      Job security  Part Time  NaN
# 3           4      Job security  Part Time  NaN
#
#                                    Q4            Q5  Q6   Q7  Q8a  Q8b  ...  \
# 0  Additional funding for Counselling            No   1   No    1    3  ...
# 1                       Drug coverage           Yes   3  Yes    3    4  ...
# 2                                 NaN            No   1   No    3    1  ...
# 3                                 NaN  I don't know   4   No    3    2  ...
#
#                                                 Q16  Q17  Q18  \
# 0                                               NaN  0.0    4
# 1             Be able to work from home once a week  0.0    3
# 2                                Give me more hours  0.0    3
# 3  more flexibility on work from home for part time  0.0    4
#
# ...

# %%
import numpy as np
List_not_change = [1, 2, 3, 4, 5, 6, np.nan]
df.loc[~df['Q4a'].isin(List_not_change), "Q4a"] = 7
df.head(4)
# Out:
#    Respondent                Q1         Q2   Q3  \
# 0           1    Increasing pay  Full Time  3.0
# 1           2  Improve benefits  Full Time  1.0
# 2           3      Job security  Part Time  NaN
# 3           4      Job security  Part Time  NaN
#
#                                    Q4            Q5  Q6   Q7  Q8a  Q8b  ...  \
# 0  Additional funding for Counselling            No   1   No    1    3  ...
# 1                       Drug coverage           Yes   3  Yes    3    4  ...
# 2                                 NaN            No   1   No    3    1  ...
# 3                                 NaN  I don't know   4   No    3    2  ...
#
#                                                 Q16  Q17  Q18  \
# 0                                               NaN  0.0    4
# 1             Be able to work from home once a week  0.0    3
# 2                                Give me more hours  0.0    3
# 3  more flexibility on work from home for part time  0.0    4
#
# ...

# %%
df.loc[df['Q4a'] == 7, "Q4b"] = df["Q4"]
df.head(6)
# Out:
#    Respondent                          Q1         Q2   Q3  \
# 0           1              Increasing pay  Full Time  3.0
# 1           2            Improve benefits  Full Time  1.0
# 2           3                Job security  Part Time  NaN
# 3           4                Job security  Part Time  NaN
# 4           5  Improve working conditions  Full Time  3.0
# 5           6              Increasing pay  Part Time  NaN
#
#                                    Q4            Q5  Q6   Q7  Q8a  Q8b  ...  \
# 0  Additional funding for Counselling            No   1   No    1    3  ...
# 1                       Drug coverage           Yes   3  Yes    3    4  ...
# 2                                 NaN            No   1   No    3    1  ...
# 3                                 NaN  I don't know   4   No    3    2  ...
# 4                    Wellness account           Yes   3   No    2    3  ...
# 5                                 NaN            No   2   No    2    1  ...
#
# ...

# %% [markdown]
# ## Coding

# %%
df["Q2"].replace({"Part Time": 1, "Full Time" : 2}, inplace=True)
df.head(4)
# Out:
#    Respondent                Q1  Q2   Q3                                  Q4  \
# 0           1    Increasing pay   2  3.0  Additional funding for Counselling
# 1           2  Improve benefits   2  1.0                       Drug coverage
# 2           3      Job security   1  NaN                                 NaN
# 3           4      Job security   1  NaN                                 NaN
#
#              Q5  Q6   Q7  Q8a  Q8b  ...  Q17  Q18  \
# 0            No   1   No    1    3  ...  0.0    4
# 1           Yes   3  Yes    3    4  ...  0.0    3
# 2            No   1   No    3    1  ...  0.0    3
# 3  I don't know   4   No    3    2  ...  0.0    4
#
#                                   Q19  Q20  \
# 0  Better lighting in the parking lot    4
# 1                                 NaN    4
# 2                                 NaN    5
# 3                                 NaN    4
#
#                                   Q21  Q22    Q23   Q24  Q4a  \
# ...

# %% [markdown]
# PRACTICE

# %% [markdown]
# Create two new variables Q1a and Q1b. For Q1a, code Q1 responses so that "Improve benefits": 1, "Improve working conditions" : 2, "Job security" : 3, "Relationship between Union and Company" : 4, "Increasing pay" : 5". Create an option 6 for the write-in response. Put the write-in responses in Q1b.

# %% [markdown]
# Replace Q5 responses with "Yes": 1, "No" : 2, "I don't know" : 3

# %% [markdown]
# Replace Q7 responses with "Yes": 1, "No" : 2, "I don't know" : 3

# %% [markdown]
# Replace Q22 responses with "Yes": 1, "No" : 2, "Prefer not to answer" : 3

# %% [markdown]
# Replace Q23 response with "North": 1, "South" : 2, "East" : 3

# %% [markdown]
# ## Manipulate

# %%
import pandas as pd
import numpy as np

# %%
df["Q24a"] = pd.cut(df["Q24"], bins=[0,5,10,15,100], labels=[1,2,3,4])
df.head(6)
# Out:
#    Respondent                          Q1  Q2   Q3  \
# 0           1              Increasing pay   2  3.0
# 1           2            Improve benefits   2  1.0
# 2           3                Job security   1  NaN
# 3           4                Job security   1  NaN
# 4           5  Improve working conditions   2  3.0
# 5           6              Increasing pay   1  NaN
#
#                                    Q4  Q5  Q6   Q7  Q8a  Q8b  ...  Q20  \
# 0  Additional funding for Counselling   2   1  2.0    1    3  ...    4
# 1                       Drug coverage   1   3  1.0    3    4  ...    4
# 2                                 NaN   2   1  2.0    3    1  ...    5
# 3                                 NaN   3   4  2.0    3    2  ...    4
# 4                    Wellness account   1   3  2.0    2    3  ...    2
# 5                                 NaN   2   2  2.0    2    1  ...    4
#
#                                                  Q21  Q22  Q23   Q24  Q4a  \
# ...

# %% [markdown]
# ## Creating Two Dataframes to Separate Qualitative Data

# %%
df_qual = ["Q1", "Q4", "Q1b", "Q4b","Q9", "Q16", "Q19","Q21"]
df2 = df.drop(df_qual, axis=1)
df2.head(4)
# Out:
#    Respondent  Q2   Q3  Q5  Q6   Q7  Q8a  Q8b  Q8c  Q8d  ...  Q15  Q17  Q18  \
# 0           1   2  3.0   2   1  2.0    1    3  2.0    6  ...    4  0.0    4
# 1           2   2  1.0   1   3  1.0    3    4  6.0    5  ...    2  0.0    3
# 2           3   1  NaN   2   1  2.0    3    1  5.0    4  ...    3  0.0    3
# 3           4   1  NaN   3   4  2.0    3    2  5.0    4  ...    2  0.0    4
#
#    Q20  Q22  Q23   Q24  Q4a  Q24a  Q1a
# 0    4    1    3  15.0    7     3    5
# 1    4    2    1   2.0    6     1    1
# 2    5    2    1   NaN  NaN   NaN    3
# 3    4    1    3   1.0  NaN     1    3
#
# [4 rows x 27 columns]

# %%
df4 = df[["Q1b", "Q4b","Q9", "Q16", "Q19","Q21"]].copy()
df4.head(4)
# Out:
#    Q1b                                 Q4b  \
# 0  NaN  Additional funding for Counselling
# 1  NaN                                 NaN
# 2  NaN                                 NaN
# 3  NaN                                 NaN
#
#                                               Q9  \
# 0                   wages keep up with inflation
# 1  Keep up with inflation. I can't pay my bills.
# 2           Additional hourly pay for onboarding
# 3                  Recognition pay for part time
#
#                                                 Q16  \
# 0                                               NaN
# 1             Be able to work from home once a week
# 2                                Give me more hours
# 3  more flexibility on work from home for part time
#
#                                   Q19                                 Q21
# 0  Better lighting in the parking lot  More women in leadership positions
# 1                                 NaN                                 NaN
# ...

# %% [markdown]
# ## Cross Tabulation

# %%
from pandas import crosstab

# %% [markdown]
# Q23 and Q3

# %%
crosstab(index=df2["Q3"], columns= df2["Q23"])
# Out:
# Q23  1  2  3
# Q3
# 1.0  1  0  1
# 2.0  4  8  2
# 3.0  1  3  6
# 4.0  3  7  6
# 5.0  1  0  0

# %%
crosstab(index=df2["Q3"], columns= df2["Q23"], normalize="columns")
# Out:
# Q23    1         2         3
# Q3
# 1.0  0.1  0.000000  0.066667
# 2.0  0.4  0.444444  0.133333
# 3.0  0.1  0.166667  0.400000
# 4.0  0.3  0.388889  0.400000
# 5.0  0.1  0.000000  0.000000

# %% [markdown]
# PRACTICE

# %% [markdown]
# Q1 and Q3

# %% [markdown]
# Q3 and Q4a

# %% [markdown]
# ## Correlation Table

# %%
import numpy as np

# %%
df_corr = df2[["Q3", "Q6", "Q8a", "Q8b", "Q8c", "Q8d", "Q8e", "Q8f", "Q10", "Q11", "Q12", "Q13", "Q14", "Q15", "Q18", "Q20"]]

# %%
df_corr.corr(method="spearman")
# Out:
#            Q3        Q6       Q8a       Q8b       Q8c       Q8d       Q8e  \
# Q3   1.000000  0.042419 -0.004557  0.009775 -0.442561 -0.005141 -0.019703
# Q6   0.042419  1.000000 -0.124559  0.136261 -0.069824  0.000040 -0.164809
# Q8a -0.004557 -0.124559  1.000000  0.096578  0.013073 -0.353649 -0.041119
# Q8b  0.009775  0.136261  0.096578  1.000000  0.252256 -0.197819 -0.217277
# Q8c -0.442561 -0.069824  0.013073  0.252256  1.000000 -0.433296  0.060330
# Q8d -0.005141  0.000040 -0.353649 -0.197819 -0.433296  1.000000 -0.006213
# Q8e -0.019703 -0.164809 -0.041119 -0.217277  0.060330 -0.006213  1.000000
# Q8f  0.157156  0.020493 -0.300756 -0.521498 -0.375420  0.030750 -0.143041
# Q10 -0.115148 -0.011903  0.112466  0.024505  0.095435 -0.177313  0.077727
# Q11  0.247230 -0.140885 -0.083822 -0.204068 -0.123748  0.087129  0.084852
# Q12  0.100544  0.168521  0.035755  0.197134 -0.079790 -0.004425 -0.059393
# Q13  0.151994  0.009321  0.090562  0.149210  0.028029 -0.161881  0.257157
# ...

# %%
df_corr.corr(method="pearson")

# %% [markdown]
# ### Correlogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_corr = df2[["Q3", "Q6", "Q10", "Q11", "Q12", "Q13", "Q14", "Q15", "Q18", "Q20"]]

# %%
corr_tab = df_corr.corr(method="spearman")

# %%
sns.heatmap(corr_tab, cmap="Greens", annot=True)

# %% [markdown]
# ## Summary Table

# %%
df2.describe()
# Out:
#        Respondent         Q2    Q3         Q5         Q6         Q7  \
# count   63.000000  63.000000  43.0  63.000000  63.000000  62.000000
# mean    32.000000   1.682540   3.0   1.888889   2.555556   1.677419
# std     18.330303   0.469227   1.0   0.764349   0.857186   0.471280
# min      1.000000   1.000000   1.0   1.000000   1.000000   1.000000
# 25%     16.500000   1.000000   2.0   1.000000   2.000000   1.000000
# 50%     32.000000   2.000000   3.0   2.000000   2.000000   2.000000
# 75%     47.500000   2.000000   4.0   2.000000   3.000000   2.000000
# max     63.000000   2.000000   5.0   3.000000   4.000000   2.000000
#
#              Q8a        Q8b        Q8c        Q8d  ...        Q13        Q14  \
# count  63.000000  63.000000  62.000000  63.000000  ...  63.000000  63.000000
# mean    3.825397   2.539683   4.612903   3.698413  ...   3.253968   3.460317
# std     1.718398   1.365773   1.653162   1.172740  ...   1.077157   0.894885
# ...
