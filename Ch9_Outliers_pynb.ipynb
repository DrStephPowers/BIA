# %% [markdown]
# <a href="https://colab.research.google.com/github/DrStephPowers/BIA/blob/main/Ch9_Outliers_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## DBSCAN Fraud Detecction

# %% [markdown]
# Credit card fraud dataset from Google Cloud or Kaggle

# %%
credit = pd.read_csv('/content/drive/MyDrive/BI BA Handbook/Chapter 9/creditcard.csv')

# %%
credit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]
# Warning: Total number of columns (31) exceeds max_columns (20) limiting to first (20) columns.

# %%
len(credit)
# Out:
# 284807

# %%
credit = credit.sample(frac=1)

# %%
credit2 = credit[:5000]

# %% [markdown]
# Use cluster analysis to detect fraud

# %%
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
df_x = ["Time", "Amount", "Class"]
x = credit2.drop(df_x, axis=1)
x.head(4)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 188316 -0.459523  0.816390 -2.199609 -1.657170  0.750212 -1.088342  0.756976
# 137627  1.025261 -1.248304  0.180253 -0.586194 -1.255391 -0.636499 -0.450901
# 153172  1.999767 -0.161425 -0.448492  0.681852 -0.446387 -0.138658 -1.017680
# 217287  1.799208 -1.341295 -1.495499 -0.522499 -0.851925 -0.513256 -0.800318
#
#               V8        V9       V10  ...       V19       V20       V21  \
# 188316 -2.040793 -1.175650  1.525709  ... -0.626595 -0.918979  1.578853
# 137627 -0.145905 -0.537023  0.545205  ...  0.600657  0.466132  0.191897
# 153172  0.087750  2.704682 -0.879032  ... -0.660902 -0.208889 -0.205941
# 217287 -0.020360  0.231186  0.021124  ...  0.140201  0.343991  0.325536
#
#              V22       V23       V24       V25       V26       V27       V28
# 188316  0.479414  0.241393 -0.391820 -1.244766  0.689565  0.570532  0.470872
# 137627 -0.053536 -0.220630 -0.121752  0.321485 -0.271312 -0.030492  0.051395
# 153172 -0.231561  0.329022  0.405984 -0.570776  0.313449 -0.022623 -0.011604
# 217287  0.529991 -0.012753  0.477861 -0.238587 -0.125993 -0.015340  0.022571
#
# [4 rows x 28 columns]

# %%
x = np.array(x)

# %%
x = StandardScaler().fit_transform(x)

# %%
KNN = NearestNeighbors(n_neighbors=2*28) #2 x number of variables
neighbors = KNN.fit(x)
distances, indices = neighbors.kneighbors(x)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]

# %%
plt.plot(distances)
plt.ylim(0, 20)
plt.show()

# %%
dbs = DBSCAN(eps=5, min_samples=2*28)
dbs.fit(x)
cl = dbs.labels_
cl
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from seaborn import scatterplot
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['lines.markersize'] = 10

# %%
scatterplot(x=credit2["V3"],y=credit2["V4"], hue=cl, palette="deep")
plt.xlabel('V1')
plt.ylabel('V2')
plt.show()

# %% [markdown]
# ## Fraud Detection Using Benford's Law

# %%
apple = pd.read_excel('/content/drive/MyDrive/BI BA Handbook/Chapter 9/apple.xlsx')

# %%
apple.head()
# Out:
#           Unnamed: 0         2023         2022         2021         2020
# 0      Total Revenue   38553360.0  394328000.0  365817000.0  277515000.0
# 1    Cost of Revenue  214137000.0  223546000.0  212981000.0  169559000.0
# 2       Gross Profit  169148000.0  172782000.0  152836000.0  111556000.0
# 3  Operating Expense   53754000.0   51345000.0   43887000.0   38668000.0
# 4   Operating Income  114301000.0  119437000.0  108949000.0   67780000.0

# %%
app = pd.concat([apple[2023], apple[2022], apple[2021], apple[2020]])
app.abs()
# Out:
# 0      38553360.0
# 1     214137000.0
# 2     169148000.0
# 3      53754000.0
# 4     114301000.0
#          ...
# 23     81020000.0
# 24    169559000.0
# 25     11056000.0
# 26     57456000.0
# 27     81020000.0
# Length: 112, dtype: float64

# %%
dig_app = app.astype(str).str[:1]
dig_app
# Out:
# 0     3
# 1     2
# 2     1
# 3     5
# 4     1
#      ..
# 23    8
# 24    1
# 25    1
# 26    5
# 27    8
# Length: 112, dtype: object

# %%
dig_app = dig_app[dig_app != '-']
dig_app = dig_app.apply(int)

# %%
freq = dig_app.value_counts().sort_index()
freq
# Out:
# 1    41
# 2    16
# 3     9
# 4     1
# 5     9
# 6     9
# 8     4
# 9    16
# Name: count, dtype: int64

# %%
plt.plot(freq.index, freq.values)
plt.xticks([])
plt.ylabel("Frequency")
plt.show()

# %%
from scipy.interpolate import make_interp_spline

# %%
def smoothify(yInput, topwordlist):
    x = np.array(range(0,len(topwordlist.index)))
    y = np.array(yInput)
    x_smooth = np.linspace(x.min(), x.max(), 600)
    spl = make_interp_spline(x, y, k=3)
    y_smooth = spl(x_smooth)
    return x_smooth, y_smooth

# %%
ziffianCurveValues = [100/i for i in range(1, len(freq.index)+1)]

# %%
x, y = smoothify(ziffianCurveValues, freq)

# %%
freq_per = freq.values/freq.values[0]*100

# %%
plt.plot(freq.index, freq_per)
plt.plot(x,y)
plt.legend(["Numbers", "Benford's Law"])
plt.xticks([])
plt.ylabel("Percent Frequency")
plt.xlabel("Index")
plt.show()

# %% [markdown]
# ## Outlier Detection Using Regression Models

# %% [markdown]
# ### Prophet Model

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.25.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.0.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.48)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
from prophet import Prophet

# %%
run = pd.read_csv('/content/drive/MyDrive/BI BA Handbook/Chapter 9/runtime.csv')

# %%
run.head()
# Out:
#           Hour  Runtime
# 0  6/9/23 0:00  1848.46
# 1  6/9/23 1:00  1828.53
# 2  6/9/23 2:00  2046.14
# 3  6/9/23 3:00  1877.21
# 4  6/9/23 4:00  1642.56

# %%
from seaborn import scatterplot
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['lines.markersize'] = 10

# %%
scatterplot(x=run["Hour"],y=run["Runtime"])
plt.xlabel('Hour')
plt.ylabel('Runtime')
plt.xticks([])
plt.show()

# %%
run['Hour'] = run['Hour'].astype('datetime64[ns]')

# %%
model = Prophet(interval_width=0.95, yearly_seasonality=True, weekly_seasonality=True)

# %%
run.rename(columns={"Hour": "ds", "Runtime": "y"}, inplace=True)

# %%
model.fit(run)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpimv4nvp_/5dk5sztx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpimv4nvp_/xbw2_c_q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5104', 'data', 'file=/tmp/tmpimv4nvp_/5dk5sztx.json', 'init=/tmp/tmpimv4nvp_/xbw2_c_q.json', 'output', 'file=/tmp/tmpimv4nvp_/prophet_modelda5_khj2/prophet_model-20240510205800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast = model.predict(run)
forecast.head()
# Out:
#                    ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0 2023-06-09 00:00:00  1955.083260  1662.480658  2393.013028  1955.083260
# 1 2023-06-09 01:00:00  1955.015727  1666.858120  2411.835472  1955.015727
# 2 2023-06-09 02:00:00  1954.948194  1712.934971  2427.894805  1954.948194
# 3 2023-06-09 03:00:00  1954.880661  1765.332193  2509.513783  1954.880661
# 4 2023-06-09 04:00:00  1954.813128  1795.877129  2553.998590  1954.813128
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  1955.083260       65.873492             65.873492             65.873492
# 1  1955.015727       85.825711             85.825711             85.825711
# 2  1954.948194      117.851464            117.851464            117.851464
# 3  1954.880661      173.615721            173.615721            173.615721
# 4  1954.813128      239.971720            239.971720            239.971720
#
#         daily  ...     weekly  weekly_lower  weekly_upper      yearly  \
# 0 -189.438448  ...  81.803714     81.803714     81.803714  173.508225
# 1 -166.306916  ...  80.308829     80.308829     80.308829  171.823798
# 2 -130.951774  ...  78.652663     78.652663     78.652663  170.150575
# 3  -71.699711  ...  76.826881     76.826881     76.826881  168.488552
# 4   -1.688010  ...  74.822005     74.822005     74.822005  166.837724
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0    173.508225    173.508225                   0.0
# 1    171.823798    171.823798                   0.0
# 2    170.150575    170.150575                   0.0
# 3    168.488552    168.488552                   0.0
# 4    166.837724    166.837724                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0  2020.956752
# 1                         0.0                         0.0  2040.841438
# 2                         0.0                         0.0  2072.799658
# 3                         0.0                         0.0  2128.496382
# 4                         0.0                         0.0  2194.784848
#
# [5 rows x 22 columns]

# %%
performance = pd.merge(run, forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']], on='ds')

# %%
performance['anomaly'] = performance.apply(lambda rows: 1 if ((rows.y<rows.yhat_lower)|(rows.y>rows.yhat_upper)) else 0, axis = 1)
anomalies = performance[performance['anomaly']==1].sort_values(by='ds')

# %%
performance.head()
# Out:
#                    ds        y         yhat   yhat_lower   yhat_upper  anomaly
# 0 2023-06-09 00:00:00  1848.46  2020.956752  1662.480658  2393.013028        0
# 1 2023-06-09 01:00:00  1828.53  2040.841438  1666.858120  2411.835472        0
# 2 2023-06-09 02:00:00  2046.14  2072.799658  1712.934971  2427.894805        0
# 3 2023-06-09 03:00:00  1877.21  2128.496382  1765.332193  2509.513783        0
# 4 2023-06-09 04:00:00  1642.56  2194.784848  1795.877129  2553.998590        1

# %%
performance['color'] = np.where(performance['anomaly']== 1, 'red', 'green')
performance['name'] = np.where(performance['anomaly'] == 1, 'Anomaly','Within Confidence Interval')
# Out:
#                    ds        y         yhat   yhat_lower   yhat_upper  \
# 0 2023-06-09 00:00:00  1848.46  2020.956752  1662.480658  2393.013028
# 1 2023-06-09 01:00:00  1828.53  2040.841438  1666.858120  2411.835472
# 2 2023-06-09 02:00:00  2046.14  2072.799658  1712.934971  2427.894805
# 3 2023-06-09 03:00:00  1877.21  2128.496382  1765.332193  2509.513783
# 4 2023-06-09 04:00:00  1642.56  2194.784848  1795.877129  2553.998590
#
#    anomaly  color                        name
# 0        0  green  Within Confidence Interval
# 1        0  green  Within Confidence Interval
# 2        0  green  Within Confidence Interval
# 3        0  green  Within Confidence Interval
# 4        1    red                     Anomaly

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = go.Figure()
fig.update_layout(
    height=800,
    title="Anomaly Detection",
    xaxis_title="Time",
    yaxis_title="Run Time (ms)",

)

fig.add_trace(go.Scatter(x=performance['ds'], y=performance['y'],
                    mode='markers',
                    name='Anomalies - Red Colored Dots',
                    marker_color=performance.color,

                        ))
fig.add_trace(go.Scatter(x=performance['ds'], y=performance['yhat'],
                    mode='lines',
                    name='Run Time',
                    marker_color="black"
                        ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="289f752c-fa78-498a-876a-b77eedec4304" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("289f752c-fa78-498a-876a-b77eedec4304")) {                    Plotly.newPlot(                        "289f752c-fa78-498a-876a-b77eedec4304",                        [{"marker":{"color":["green","green","green","green","red","red","green","green","green","green","green","green","green","green","red","red","red","green","green","red","green","green","green","green","green","green","green","green","green","green","green","red","green","red","green","green","green","green","red","red","green","green","green","green","green","green","green","green","green","green","green","red","red","red","green","green","green","green","green","green","red","red","green","red","red","red","green","green","green","green","green","green","red","green","green","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","red","green","green","green","green","green","green","green","green","red","red","green","green","red","red","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","red","green","green","green","green","green","green","green","red","green","red","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green", ...
